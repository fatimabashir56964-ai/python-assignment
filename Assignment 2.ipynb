# %%
list = [1,2,3,4,5,6,7,8,9,0]
print("Lenght of list is:",len(list))
# Out:
# Lenght of list is: 10

# %%
list = [1,2,3,4,5,6,7,8,9,0]
total = sum(list)
print("Sum all numeric in list:",total)
# Out:
# Sum all numeric in list: 45

# %%
list = [1,2,3,4,5,6,7,8,9,0]
largenum = max(list)
print("Larger number in this list is:",largenum)
# Out:
# Larger number in this list is: 9

# %%
a = [1,1,2,3,5,8,13,21,]
